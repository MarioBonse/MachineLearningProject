# %%
import pandas as pd
import numpy as np
from matplotlib import gridspec
import math

# %%
df = pd.read_csv("CSVResult/CSVResultFinal.csv")
df = df.drop(0).reset_index()
df = df.drop(columns = ['degree', 'coef',
 'Validation foldN _0',
 'Validation foldN _1',
 'Validation foldN _2',
 'Validation foldN _3',
 'Validation foldN _4',
 'Training foldN _0',
 'Training foldN _1',
 'Training foldN _2',
 'Training foldN _3',
 'Training foldN _4', 'time','kernel'])

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df=df.astype('float')
df
# Out:
#       index  Validation mean  Validation deviation  Training mean  \
# 0       1.0         0.758788              0.330935       0.000370
# 1       2.0         0.758788              0.330935       0.000370
# 2       3.0         0.758788              0.330935       0.000370
# 3       4.0         0.758788              0.330935       0.000370
# 4       5.0         0.759530              0.330776       0.001526
# 5       6.0         0.759530              0.330776       0.001526
# 6       7.0         0.759530              0.330776       0.001526
# 7       8.0         0.759530              0.330776       0.001526
# 8       9.0         0.767699              0.329094       0.014201
# 9      10.0         0.767699              0.329094       0.014201
# 10     11.0         0.767699              0.329094       0.014201
# 11     12.0         0.767699              0.329094       0.014201
# 12     13.0         0.805662              0.344074       0.031203
# 13     14.0         0.806364              0.343915       0.032292
# 14     15.0         0.814099              0.342208       0.044391
# 15     16.0         0.848125              0.312488       0.138189
# 16     17.0         0.848125              0.312488       0.138189
# 17     18.0         0.848125              0.312488       0.138189
# 18     19.0         0.848125              0.312488       0.138189
# 19     20.0         0.890390              0.325200       0.163165
# 20     21.0         0.941193              0.146885       0.440109
# 21     22.0         0.941422              0.146731       0.440606
# 22     23.0         0.944176              0.145011       0.446309
# 23     24.0         0.967320              0.131781       0.505041
# 24     25.0         0.971237              0.233080       0.141279
# 25     26.0         0.971350              0.232854       0.142155
# 26     27.0         0.973240              0.230163       0.152208
# 27     28.0         0.994439              0.201491       0.253101
# 28     29.0         1.001018              0.103655       0.751491
# 29     30.0         1.001113              0.103607       0.751720
# ..      ...              ...                   ...            ...
# 970   971.0         8.621666              0.133416       8.562009
# 971   972.0         8.621674              0.133416       8.562016
# 972   973.0         8.621674              0.133416       8.562016
# 973   974.0         8.621674              0.133416       8.562016
# 974   975.0         8.621674              0.133416       8.562016
# 975   976.0         8.621695              0.145101       8.576824
# 976   977.0         8.621714              0.145101       8.576843
# 977   978.0         8.621719              0.133434       8.562230
# 978   979.0         8.621723              0.144942       8.576564
# 979   980.0         8.621742              0.144942       8.576582
# 980   981.0         8.621784              0.144904       8.576616
# 981   982.0         8.621803              0.144904       8.576635
# 982   983.0         8.622533              0.145086       8.577504
# 983   984.0         8.622541              0.145087       8.577512
# 984   985.0         8.622541              0.145087       8.577512
# 985   986.0         8.622541              0.145087       8.577512
# 986   987.0         8.622541              0.145087       8.577512
# 987   988.0         8.622573              0.144934       8.577249
# 988   989.0         8.622581              0.144934       8.577257
# 989   990.0         8.622581              0.144934       8.577257
# 990   991.0         8.622581              0.144934       8.577257
# 991   992.0         8.622581              0.144934       8.577257
# 992   993.0         8.622606              0.145101       8.577743
# 993   994.0         8.622633              0.144949       8.577478
# 994   995.0         8.622634              0.144896       8.577302
# 995   996.0         8.622642              0.144897       8.577310
# 996   997.0         8.622642              0.144897       8.577310
# 997   998.0         8.622642              0.144897       8.577310
# 998   999.0         8.622642              0.144897       8.577310
# 999  1000.0         8.622694              0.144911       8.577531
#
#      Training deviation            C  epsilon        gamma
# 0              0.000005     100.0000   0.0001       1.0000
# 1              0.000005    1000.0000   0.0001       1.0000
# 2              0.000005   10000.0000   0.0001       1.0000
# 3              0.000005  100000.0000   0.0001       1.0000
# 4              0.000012     100.0000   0.0010       1.0000
# 5              0.000012    1000.0000   0.0010       1.0000
# 6              0.000012   10000.0000   0.0010       1.0000
# 7              0.000012  100000.0000   0.0010       1.0000
# 8              0.000013     100.0000   0.0100       1.0000
# 9              0.000013    1000.0000   0.0100       1.0000
# 10             0.000013   10000.0000   0.0100       1.0000
# 11             0.000013  100000.0000   0.0100       1.0000
# 12             0.006220      10.0000   0.0001       1.0000
# 13             0.006210      10.0000   0.0010       1.0000
# 14             0.006124      10.0000   0.0100       1.0000
# 15             0.000397     100.0000   0.1000       1.0000
# 16             0.000397    1000.0000   0.1000       1.0000
# 17             0.000397   10000.0000   0.1000       1.0000
# 18             0.000397  100000.0000   0.1000       1.0000
# 19             0.005419      10.0000   0.1000       1.0000
# 20             0.026303     100.0000   0.0001       0.1000
# 21             0.026266     100.0000   0.0010       0.1000
# 22             0.025847     100.0000   0.0100       0.1000
# 23             0.022383     100.0000   0.1000       0.1000
# 24             0.026872    1000.0000   0.0001       0.1000
# 25             0.026833    1000.0000   0.0010       0.1000
# 26             0.026507    1000.0000   0.0100       0.1000
# 27             0.023027    1000.0000   0.1000       0.1000
# 28             0.028745      10.0000   0.0001       0.1000
# 29             0.028730      10.0000   0.0010       0.1000
# ..                  ...          ...      ...          ...
# 970            0.051017       0.0001   1.0000      10.0000
# 971            0.051017       0.0001   1.0000     100.0000
# 972            0.051017       0.0001   1.0000    1000.0000
# 973            0.051017       0.0001   1.0000   10000.0000
# 974            0.051017       0.0001   1.0000  100000.0000
# 975            0.050397       0.0010   0.0100       0.0001
# 976            0.050397       0.0001   0.0100       0.0010
# 977            0.051019       0.0001   1.0000       0.0001
# 978            0.050395       0.0010   0.0001       0.0001
# 979            0.050395       0.0001   0.0001       0.0010
# 980            0.050429       0.0010   0.0010       0.0001
# 981            0.050429       0.0001   0.0010       0.0010
# 982            0.050393       0.0001   0.0100      10.0000
# 983            0.050393       0.0001   0.0100     100.0000
# 984            0.050393       0.0001   0.0100    1000.0000
# 985            0.050393       0.0001   0.0100   10000.0000
# 986            0.050393       0.0001   0.0100  100000.0000
# 987            0.050386       0.0001   0.0001      10.0000
# 988            0.050386       0.0001   0.0001     100.0000
# 989            0.050386       0.0001   0.0001    1000.0000
# 990            0.050386       0.0001   0.0001   10000.0000
# 991            0.050386       0.0001   0.0001  100000.0000
# 992            0.050394       0.0001   0.0100       0.0001
# 993            0.050387       0.0001   0.0001       0.0001
# 994            0.050420       0.0001   0.0010      10.0000
# 995            0.050420       0.0001   0.0010     100.0000
# 996            0.050420       0.0001   0.0010    1000.0000
# 997            0.050420       0.0001   0.0010   10000.0000
# 998            0.050420       0.0001   0.0010  100000.0000
# 999            0.050421       0.0001   0.0010       0.0001
#
# [1000 rows x 8 columns]

# %%
C=np.log10(df.values[:,5]);
gamma=np.log10(df.values[:,6]);
epsilon=np.log10(df.values[:,7]);
validationmeanerror=df.values[:,1];
validationmeanvariance=df.values[:,2];

# %%
fig = plt.figure(figsize=(11,8))


ax2 = fig.add_subplot(111,projection='3d')
ax2.set_ylabel("log10(gamma)")
ax2.set_zlabel("log10(epsilon)")
ax2.set_xlabel("log10(C)")
ax2.set_ylim(-1000, 1000)
ax2.set_xlim(-1000,1000)
ax2.set_zlim(-1000,1000)
surf2=ax.scatter(10^C, 10^gamma, 10^epsilon, c=validationmeanvariance, cmap=plt.set_cmap('viridis'))
fig.colorbar(surf2, shrink=2, aspect=5)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1099.4666666666667">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-173-a0d3eb6847ac> in <module>
#       9 ax2.set_xlim(-1000,1000)
#      10 ax2.set_zlim(-1000,1000)
# ---> 11 surf2=ax.scatter(10^C, 10^gamma, 10^epsilon, c=validationmeanvariance, cmap=plt.set_cmap('viridis'))
#      12 fig.colorbar(surf2, shrink=2, aspect=5)
#      13
#
# TypeError: ufunc 'bitwise_xor' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
fig = plt.figure(figsize=(11,8))
ax = fig.add_subplot(111,projection='3d')
ax.set_ylabel("log10(gamma)")
ax.set_zlabel("log10(epsilon)")
ax.set_xlabel("log10(C)")



surf = ax.scatter(C, gamma, epsilon, c=validationmeanerror, cmap = plt.set_cmap('viridis'))
fig.colorbar(surf, shrink=0.5, aspect=5)
# Out:
# <img src="data:image/png;base64,..." width="969">

# %%
??fig.colorbar
