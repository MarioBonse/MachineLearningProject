# %%
import pandas as pd
import numpy as np
from matplotlib import gridspec
import math

# %%
df = pd.read_csv("CSVResult/CSVResultFinal.csv")
df = df.drop(0).reset_index()
df = df.drop(columns = ['degree', 'coef',
 'Validation foldN _0',
 'Validation foldN _1',
 'Validation foldN _2',
 'Validation foldN _3',
 'Validation foldN _4',
 'Training foldN _0',
 'Training foldN _1',
 'Training foldN _2',
 'Training foldN _3',
 'Training foldN _4', 'time','kernel'])

# %%
df
# Out:
#      index     Validation mean Validation deviation          Training mean  \
# 0        1  0.7587881556608178   0.3309348525106945  0.0003697847479853421
# 1        2  0.7587881556608178   0.3309348525106945  0.0003697847479853421
# 2        3  0.7587881556608178   0.3309348525106945  0.0003697847479853421
# 3        4  0.7587881556608178   0.3309348525106945  0.0003697847479853421
# 4        5  0.7595304007084096  0.33077597726155566  0.0015255711678666289
# 5        6  0.7595304007084096  0.33077597726155566  0.0015255711678666289
# 6        7  0.7595304007084096  0.33077597726155566  0.0015255711678666289
# 7        8  0.7595304007084096  0.33077597726155566  0.0015255711678666289
# 8        9   0.767699377265229   0.3290936285853693   0.014201431552104002
# 9       10   0.767699377265229   0.3290936285853693   0.014201431552104002
# 10      11   0.767699377265229   0.3290936285853693   0.014201431552104002
# 11      12   0.767699377265229   0.3290936285853693   0.014201431552104002
# 12      13  0.8056618407061137  0.34407411845055763   0.031202986454422026
# 13      14  0.8063636729784172   0.3439150048582262   0.032292353791818204
# 14      15   0.814099175711166  0.34220817564789874    0.04439078346743318
# 15      16  0.8481248437766699  0.31248786209131374    0.13818925416466904
# 16      17  0.8481248437766699  0.31248786209131374    0.13818925416466904
# 17      18  0.8481248437766699  0.31248786209131374    0.13818925416466904
# 18      19  0.8481248437766699  0.31248786209131374    0.13818925416466904
# 19      20  0.8903896840218376  0.32519951074260406    0.16316507018972645
# 20      21  0.9411927034536174  0.14688509989849324     0.4401091219682748
# 21      22  0.9414219015236158  0.14673065707870844     0.4406056957138185
# 22      23  0.9441756822976142   0.1450113324197263     0.4463086020112046
# 23      24  0.9673202368812477  0.13178050434814784     0.5050407346266874
# 24      25  0.9712372461448732  0.23308048066239484    0.14127871165307024
# 25      26  0.9713497378937547   0.2328542870740257    0.14215486501952052
# 26      27  0.9732404426525288   0.2301629455520992    0.15220810554106837
# 27      28  0.9944394160628309  0.20149087753713282     0.2531007623465123
# 28      29  1.0010178192900177   0.1036545168082627     0.7514910839607823
# 29      30  1.0011125544598531  0.10360717075838578     0.7517199021515011
# ..     ...                 ...                  ...                    ...
# 970    971   8.621665604543962  0.13341570874507455      8.562008648871224
# 971    972   8.621673554246504  0.13341594246693922      8.562016495866194
# 972    973    8.62167355432382   0.1334159424887745         8.562016495922
# 973    974    8.62167355432382   0.1334159424887745         8.562016495922
# 25      0.02683309584641487    1000   0.001     0.1
# 26     0.026507182742205076    1000    0.01     0.1
# 27      0.02302743197577468    1000     0.1     0.1
# 28      0.02874466065186096      10  0.0001     0.1
# 29     0.028730171446027252      10   0.001     0.1
# ..                      ...     ...     ...     ...
# 970     0.05101717066453235  0.0001       1      10
# 971    0.051017462198331816  0.0001       1     100
# 972    0.051017462212263304  0.0001       1    1000
# 973    0.051017462212263304  0.0001       1   10000
# 974    0.051017462212263304  0.0001       1  100000
# 975      0.0503971822426562   0.001    0.01  0.0001
# 976     0.05039707875968922  0.0001    0.01   0.001
# 977    0.051018584033576383  0.0001       1  0.0001
# 978     0.05039501169240213   0.001  0.0001  0.0001
# 979    0.050394850308478525  0.0001  0.0001   0.001
# 980      0.0504287952703261   0.001   0.001  0.0001
# 981    0.050428633927269054  0.0001   0.001   0.001
# 982     0.05039309182559273  0.0001    0.01      10
# 983     0.05039273690384577  0.0001    0.01     100
# 984     0.05039273691779521  0.0001    0.01    1000
# 985     0.05039273691779521  0.0001    0.01   10000
# 986     0.05039273691779521  0.0001    0.01  100000
# 987    0.050386454917601416  0.0001  0.0001      10
# 988     0.05038616648668358  0.0001  0.0001     100
# 989     0.05038616650034912  0.0001  0.0001    1000
# 990     0.05038616650034912  0.0001  0.0001   10000
# 991     0.05038616650034912  0.0001  0.0001  100000
# 992     0.05039350743825387  0.0001    0.01  0.0001
# 993       0.050386995062663  0.0001  0.0001  0.0001
# 994    0.050420225859781925  0.0001   0.001      10
# 995    0.050419937370485605  0.0001   0.001     100
# 996     0.05041993738417648  0.0001   0.001    1000
# 997     0.05041993738417648  0.0001   0.001   10000
# 998     0.05041993738417648  0.0001   0.001  100000
# 999     0.05042078784677534  0.0001   0.001  0.0001
#
# [1000 rows x 8 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df=df.astype('float')

# %%
C=np.log10(df.values[:,5]);
gamma=np.log10(df.values[:,6]);
epsilon=np.log10(df.values[:,7]);
validationresult=df.values[:,1];
trainingresult=df.values[:,3];
trainingresult;

# %%
fig = plt.figure(figsize=(11,8))
ax = fig.add_subplot(122,projection='3d')
ax.set_ylabel("log10(gamma)")
ax.set_zlabel("log10(epsilon)")
ax.set_xlabel("log10(C)")



surf=ax.scatter(C, gamma, epsilon, c=validationresult, cmap=plt.cool())
fig.colorbar(surf, shrink=0.5, aspect=5)


ax2 = fig.add_subplot(121,projection='3d')
ax2.set_ylabel("log10(gamma)")
ax2.set_zlabel("log10(epsilon)")
ax2.set_xlabel("log10(C)")
surf2=ax.scatter(C, gamma, epsilon, c=trainingresult, cmap=plt.cool())
fig.colorbar(surf2, shrink=2, aspect=5)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1099.4666666666667">

# %%
help colormaps
# Out:
#   File "<ipython-input-88-1ff0b9a98467>", line 1
#     help colormaps
#                  ^
# SyntaxError: invalid syntax

# %%
??fig.colorbar
