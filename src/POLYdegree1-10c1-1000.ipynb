# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../result/RBFC_gamma2.csv")
df = df.drop(0).reset_index()
df = df.drop(columns = ['degree', 'coef',
 'Validation foldN _0',
 'Validation foldN _1',
 'Validation foldN _2',
 'Validation foldN _3',
 'Validation foldN _4',
 'Training foldN _0',
 'Training foldN _1',
 'Training foldN _2',
 'Training foldN _3',
 'Training foldN _4', 'time', 'epsilon', 'index','Validation deviation','Training mean',
    'Training deviation', 'kernel'])
df = df.astype('float')
df = df.sort_values(by = ["C", "gamma"])
df = df.round(2)
df = df.pivot("C", "gamma", "Validation mean")
ax = sns.heatmap(df, cmap="BrBG")

# %%
ax = sns.heatmap(df, cmap="BrBG")

# %%
df = pd.read_csv("../result/RBFC_gamma1.csv")
df = df.drop(0).reset_index()
df = df.drop(columns = ['degree', 'coef',
 'Validation foldN _0',
 'Validation foldN _1',
 'Validation foldN _2',
 'Validation foldN _3',
 'Validation foldN _4',
 'Training foldN _0',
 'Training foldN _1',
 'Training foldN _2',
 'Training foldN _3',
 'Training foldN _4', 'time', 'epsilon', 'index','Validation mean','Training mean',
    'Training deviation', 'kernel'])
df = df.astype('float')
df = df.sort_values(by = ["C", "gamma"])
df = df.round(2)
df = df.pivot("C", "gamma", "Validation deviation")

# %%
ax = sns.heatmap(df)

# %%
ax = sns.heatmap(df, cmap="BrBG")

# %%
mat[:,1] = mat[:,1].round(0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-3813e8a7b24f> in <module>
# ----> 1 mat[:,1] = mat[:,1].round(0).astype(int)
#
# AttributeError: 'str' object has no attribute 'rint'

# %%
df
# Out:
# C                                   1.0                10.0  \
# gamma
# 0.1                  1.2767374774292963  1.0490125929525376
# 0.2                  1.1934707005351681  0.9517966889285028
# 0.30000000000000004    1.20176376663054   0.833562174409739
# 0.4                  1.2435314593539226  0.7309330538008865
# 0.5                  1.2997900700105505  0.6684005437614889
# 0.6                  1.3578670676805982  0.6516367797663625
# 0.7000000000000001   1.4272596038079395  0.6557297787955791
# 0.8                  1.5087098884272592  0.6706007860004191
# 0.9                  1.5955731197581557  0.6890104964852002
# 1.0                  1.6971787295737382  0.7138282262478274
#
# C                                 100.0                11.0  \
# gamma
# 0.1                  0.9575562005786603  1.0415877343300406
# 0.2                  0.6907943646857968  0.9426401265761986
# 0.30000000000000004  0.6026524307533231   0.820774058223598
# ...

# %%
df = pd.read_csv("../result/POLY_degree1-10_C1-1000.csv")
df = df.drop(0).reset_index()
df = df.drop(columns = ['degree', 'coef',
 'Validation foldN _0',
 'Validation foldN _1',
 'Validation foldN _2',
 'Validation foldN _3',
 'Validation foldN _4',
 'Training foldN _0',
 'Training foldN _1',
 'Training foldN _2',
 'Training foldN _3',
 'Training foldN _4', 'time', 'epsilon', 'index','Validation deviation','Training mean',
    'Training deviation', 'kernel'])
df = df.astype('float')
df = df.sort_values(by = ["C", "gamma"])
df = df.round(2)
df = df.pivot("C", "gamma", "Validation mean")
ax = sns.heatmap(df, cmap="BrBG")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f8346c98aa73> in <module>
#      16 df = df.sort_values(by = ["C", "gamma"])
#      17 df = df.round(2)
# ---> 18 df = df.pivot("C", "gamma", "Validation mean")
#      19 ax = sns.heatmap(df, cmap="BrBG")
#
# ~/git/MachineLearningProject/venv/lib/python3.5/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5192         """
#    5193         from pandas.core.reshape.reshape import pivot
# -> 5194         return pivot(self, index=index, columns=columns, values=values)
#    5195
#    5196     _shared_docs['pivot_table'] = """
#
# ~/git/MachineLearningProject/venv/lib/python3.5/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     413             indexed = self._constructor_sliced(self[values].values,
# ...

# %%
df = pd.read_csv("../result/POLY_degree1-10_C1-1000.csv")
df = df.drop(0).reset_index()
df = df.drop(columns = [ 'coef',
  'time', 'epsilon', 'index',
     'kernel'])
df = df.astype('float')
df = df.round(3)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fmri = sns.load_dataset("fmri")
ax = sns.lineplot(x="C", y="Validation mean", data=df)

# %%
df
# Out:
#      Validation mean  Validation deviation  Training mean  Training deviation  \
# 0              1.344                 0.098          1.260               0.022
# 1              1.150                 0.103          0.973               0.028
# 2              0.952                 0.094          0.715               0.024
# 3              0.814                 0.118          0.532               0.023
# 4              0.788                 0.160          0.387               0.026
# 5              0.795                 0.207          0.246               0.026
# 6              0.815                 0.273          0.129               0.020
# 7              0.904                 0.371          0.057               0.014
# 8              1.051                 0.464          0.021               0.007
# 9              2.006                 0.131          1.971               0.033
# 10             1.334                 0.100          1.247               0.021
# ...

# %%
df_04 = df.loc[df['degree'] == 1]
df_05 = df.loc[df['degree'] == 2]
df_06 = df.loc[df['degree'] == 3]
df_07 = df.loc[df['degree'] == 4]
df_08 = df.loc[df['degree'] == 5]
df_09 = df.loc[df['degree'] == 6]
df_10 = df.loc[df['degree'] == 7]
df_11 = df.loc[df['degree'] == 8]
df_12 = df.loc[df['degree'] == 9]
df_13 = df.loc[df['degree'] == 10]

# %%
df_04_0 = df_04[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_04[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_04[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_04[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_04[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result01 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
df_04_0 = df_05[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_05[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_05[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_05[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_05[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result02 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
df_04_0 = df_06[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_06[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_06[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_06[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_06[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result03 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
df_04_0 = df_07[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_07[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_07[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_07[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_07[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result04 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
df_04_0 = df_08[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_08[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_08[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_08[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_08[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result05 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
df_04_0 = df_09[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_09[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_09[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_09[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_09[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result06 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
df_04_0 = df_10[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_10[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_10[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_10[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_10[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result07 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
df_04_0 = df_11[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_11[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_11[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_11[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_11[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result08 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
df_04_0 = df_12[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_12[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_12[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_12[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_12[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result09 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
df_04_0 = df_13[["C", "Validation foldN _0", 'Training foldN _0']].rename(index=str, columns={"Validation foldN _0":"validationerror",'Training foldN _0':"trainingerror"})
df_04_1 = df_13[["C", "Validation foldN _1", 'Training foldN _1']].rename(index=str, columns={"Validation foldN _1":"validationerror",'Training foldN _1':"trainingerror"})
df_04_2 = df_13[["C", "Validation foldN _2", 'Training foldN _2']].rename(index=str, columns={"Validation foldN _2":"validationerror",'Training foldN _2':"trainingerror"})
df_04_3 = df_13[["C", "Validation foldN _3", 'Training foldN _3']].rename(index=str, columns={"Validation foldN _3":"validationerror",'Training foldN _3':"trainingerror"})
df_04_4 = df_13[["C", "Validation foldN _4", 'Training foldN _4']].rename(index=str, columns={"Validation foldN _4":"validationerror",'Training foldN _4':"trainingerror"})
result10 = pd.concat([df_04_0,df_04_1,df_04_2,df_04_3,df_04_4]).reset_index()

# %%
ax = sns.lineplot(x="C", y="validationerror",data=result01)
ax = sns.lineplot(x="C", y="trainingerror",data=result01)
ax.legend(["validationerror", "trainingerror"])

# %%
??plt.subplot

# %%
f, axes = plt.subplots(1, 5)
f.set_size_inches(30, 5)
ax = sns.lineplot(x="C", y="validationerror",data=result01,ax=axes[0])
ax = sns.lineplot(x="C", y="trainingerror",data=result01, ax=axes[0])
ax.legend(["validationerror", "trainingerror"])
ax = sns.lineplot(x="C", y="validationerror",data=result02,ax=axes[1] )
ax = sns.lineplot(x="C", y="trainingerror",data=result02,ax=axes[1])
ax.legend(["validationerror", "trainingerror"])
ax = sns.lineplot(x="C", y="validationerror",data=result03,ax=axes[2] )
ax = sns.lineplot(x="C", y="trainingerror",data=result03,ax=axes[2])
ax.legend(["validationerror", "trainingerror"])
ax = sns.lineplot(x="C", y="validationerror",data=result04,ax=axes[3] )
ax = sns.lineplot(x="C", y="trainingerror",data=result04,ax=axes[3])
ax.legend(["validationerror", "trainingerror"])
ax = sns.lineplot(x="C", y="validationerror",data=result05,ax=axes[4] )
ax = sns.lineplot(x="C", y="trainingerror",data=result05,ax=axes[4])
ax.legend(["validationerror", "trainingerror"])

# %%
f, axes = plt.subplots(1, 5)
f.set_size_inches(25, 5)
ax = sns.lineplot(x="C", y="validationerror",data=result06,ax=axes[0])
ax = sns.lineplot(x="C", y="trainingerror",data=result06, ax=axes[0])
ax.legend(["validationerror", "trainingerror"])
ax = sns.lineplot(x="C", y="validationerror",data=result07,ax=axes[1] )
ax = sns.lineplot(x="C", y="trainingerror",data=result07,ax=axes[1])
ax.legend(["validationerror", "trainingerror"])
ax = sns.lineplot(x="C", y="validationerror",data=result08,ax=axes[2] )
ax = sns.lineplot(x="C", y="trainingerror",data=result08,ax=axes[2])
ax.legend(["validationerror", "trainingerror"])
ax = sns.lineplot(x="C", y="validationerror",data=result09,ax=axes[3] )
ax = sns.lineplot(x="C", y="trainingerror",data=result09,ax=axes[3])
ax.legend(["validationerror", "trainingerror"])
ax = sns.lineplot(x="C", y="validationerror",data=result10,ax=axes[4] )
ax = sns.lineplot(x="C", y="trainingerror",data=result10,ax=axes[4])
ax.legend(["validationerror", "trainingerror"])

# %%
ax = sns.lineplot(x="C", y="validationerror",data=result04)
ax = sns.lineplot(x="C", y="trainingerror",data=result04)

# %%
ax = sns.lineplot(x="C", y="validationerror",data=result05)
ax = sns.lineplot(x="C", y="trainingerror",data=result05)

# %%
ax = sns.lineplot(x="C", y="validationerror",data=result06)
ax = sns.lineplot(x="C", y="trainingerror",data=result06)

# %%
ax = sns.lineplot(x="C", y="validationerror",data=result07)
ax = sns.lineplot(x="C", y="trainingerror",data=result07)

# %%
ax = sns.lineplot(x="C", y="validationerror",data=result08)
ax = sns.lineplot(x="C", y="trainingerror",data=result08)

# %%
ax = sns.lineplot(x="C", y="validationerror",data=result09)
ax = sns.lineplot(x="C", y="trainingerror",data=result09)

# %%
ax = sns.lineplot(x="C", y="validationerror",data=result10)
ax = sns.lineplot(x="C", y="trainingerror",data=result10)

# %%
??sns.lineplot
